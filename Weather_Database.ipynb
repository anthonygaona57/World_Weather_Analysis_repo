# %%
import requests 
from config import weather_api_key
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
#print(city_url)

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_weather_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | tiksi
# Processing Record 7 of Set 1 | pevek
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | aguimes
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | mindelo
# Processing Record 13 of Set 1 | yerbogachen
# Processing Record 14 of Set 1 | luderitz
# Processing Record 15 of Set 1 | goderich
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | pasighat
# Processing Record 18 of Set 1 | severo-kurilsk
# Processing Record 19 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 1 | laguna
# Processing Record 21 of Set 1 | ilulissat
# Processing Record 22 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 1 | vaitape
# Processing Record 24 of Set 1 | dikson
# Processing Record 25 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 1 | porto novo
# Processing Record 27 of Set 1 | skagastrond
# City not found. Skipping...
# Processing Record 28 of Set 1 | stantsiya gorchakovo
# City not found. Skipping...
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | lata
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | geraldton
# Processing Record 33 of Set 1 | anadyr
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | bereda
# Processing Record 36 of Set 1 | saldanha
# Processing Record 37 of Set 1 | itarema
# Processing Record 38 of Set 1 | alofi
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | fairbanks
# Processing Record 41 of Set 1 | nikolskoye
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | jodhpur
# Processing Record 44 of Set 1 | clyde river
# Processing Record 45 of Set 1 | ao luk
# City not found. Skipping...
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 1 | san jose
# Processing Record 49 of Set 1 | mackenzie
# Processing Record 50 of Set 1 | skalistyy
# City not found. Skipping...
# Processing Record 1 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | tanah merah
# Processing Record 4 of Set 2 | homer
# Processing Record 5 of Set 2 | ajuchitlan
# Processing Record 6 of Set 2 | avarua
# Processing Record 7 of Set 2 | helong
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | nanortalik
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 2 | airai
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 2 | asbe teferi
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | bluff
# Processing Record 18 of Set 2 | vao
# Processing Record 19 of Set 2 | san patricio
# Processing Record 20 of Set 2 | norman wells
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | tjome
# Processing Record 23 of Set 2 | longyearbyen
# Processing Record 24 of Set 2 | tual
# Processing Record 25 of Set 2 | narsaq
# Processing Record 26 of Set 2 | te anau
# Processing Record 27 of Set 2 | roald
# Processing Record 28 of Set 2 | qaanaaq
# Processing Record 29 of Set 2 | brae
# Processing Record 30 of Set 2 | kahului
# Processing Record 31 of Set 2 | alice springs
# Processing Record 32 of Set 2 | punta arenas
# Processing Record 33 of Set 2 | la crosse
# Processing Record 34 of Set 2 | samoded
# Processing Record 35 of Set 2 | minbu
# Processing Record 36 of Set 2 | chokurdakh
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 2 | dalvik
# Processing Record 39 of Set 2 | show low
# Processing Record 40 of Set 2 | mar del plata
# Processing Record 41 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 2 | san cristobal
# Processing Record 44 of Set 2 | north bend
# Processing Record 45 of Set 2 | talnakh
# Processing Record 46 of Set 2 | tomatlan
# Processing Record 47 of Set 2 | souillac
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | mataura
# Processing Record 50 of Set 2 | russkiy kameshkir
# Processing Record 1 of Set 3 | lima
# Processing Record 2 of Set 3 | olga
# Processing Record 3 of Set 3 | huayang
# Processing Record 4 of Set 3 | castro
# Processing Record 5 of Set 3 | mul
# Processing Record 6 of Set 3 | manta
# Processing Record 7 of Set 3 | margate
# Processing Record 8 of Set 3 | hobart
# Processing Record 9 of Set 3 | hofn
# Processing Record 10 of Set 3 | barrow
# Processing Record 11 of Set 3 | pisco
# Processing Record 12 of Set 3 | mogadishu
# Processing Record 13 of Set 3 | solton
# Processing Record 14 of Set 3 | yinchuan
# Processing Record 15 of Set 3 | cherskiy
# Processing Record 16 of Set 3 | alamos
# Processing Record 17 of Set 3 | palana
# Processing Record 18 of Set 3 | outlook
# Processing Record 19 of Set 3 | douentza
# Processing Record 20 of Set 3 | vila franca do campo
# Processing Record 21 of Set 3 | santa maria
# Processing Record 22 of Set 3 | quatre cocos
# Processing Record 23 of Set 3 | noumea
# Processing Record 24 of Set 3 | tuatapere
# Processing Record 25 of Set 3 | flin flon
# Processing Record 26 of Set 3 | shache
# Processing Record 27 of Set 3 | grand gaube
# Processing Record 28 of Set 3 | rio gallegos
# Processing Record 29 of Set 3 | san isidro
# Processing Record 30 of Set 3 | thompson
# Processing Record 31 of Set 3 | saint-philippe
# Processing Record 32 of Set 3 | bubaque
# Processing Record 33 of Set 3 | dingle
# Processing Record 34 of Set 3 | cubulco
# Processing Record 35 of Set 3 | mizdah
# Processing Record 36 of Set 3 | karratha
# Processing Record 37 of Set 3 | grootfontein
# Processing Record 38 of Set 3 | faanui
# Processing Record 39 of Set 3 | umm kaddadah
# Processing Record 40 of Set 3 | wilmington
# Processing Record 41 of Set 3 | crab hill
# City not found. Skipping...
# Processing Record 42 of Set 3 | port hedland
# Processing Record 43 of Set 3 | half moon bay
# Processing Record 44 of Set 3 | cassilandia
# Processing Record 45 of Set 3 | lozuvatka
# Processing Record 46 of Set 3 | yellowknife
# Processing Record 47 of Set 3 | nalut
# Processing Record 48 of Set 3 | bengkulu
# Processing Record 49 of Set 3 | egvekinot
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 4 | khatanga
# Processing Record 3 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 4 | mujiayingzi
# Processing Record 5 of Set 4 | dalbandin
# Processing Record 6 of Set 4 | olafsvik
# Processing Record 7 of Set 4 | togur
# Processing Record 8 of Set 4 | sola
# Processing Record 9 of Set 4 | ahipara
# Processing Record 10 of Set 4 | new norfolk
# Processing Record 11 of Set 4 | sambava
# Processing Record 12 of Set 4 | clones
# Processing Record 13 of Set 4 | maniitsoq
# Processing Record 14 of Set 4 | yenagoa
# Processing Record 15 of Set 4 | cabo san lucas
# Processing Record 16 of Set 4 | saint anthony
# Processing Record 17 of Set 4 | tpig
# Processing Record 18 of Set 4 | conway
# Processing Record 19 of Set 4 | timra
# Processing Record 20 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 4 | mahebourg
# Processing Record 22 of Set 4 | saskylakh
# Processing Record 23 of Set 4 | cockburn town
# Processing Record 24 of Set 4 | leningradskiy
# Processing Record 25 of Set 4 | leh
# Processing Record 26 of Set 4 | tiarei
# Processing Record 27 of Set 4 | the valley
# Processing Record 28 of Set 4 | kodiak
# Processing Record 29 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 4 | saint-francois
# Processing Record 31 of Set 4 | san rafael del sur
# Processing Record 32 of Set 4 | chuy
# Processing Record 33 of Set 4 | deputatskiy
# Processing Record 34 of Set 4 | padang
# Processing Record 35 of Set 4 | asau
# Processing Record 36 of Set 4 | maceio
# Processing Record 37 of Set 4 | xapuri
# Processing Record 38 of Set 4 | labuhan
# Processing Record 39 of Set 4 | jacmel
# Processing Record 40 of Set 4 | pandan
# Processing Record 41 of Set 4 | camacha
# Processing Record 42 of Set 4 | noyabrsk
# Processing Record 43 of Set 4 | kavaratti
# Processing Record 44 of Set 4 | butaritari
# Processing Record 45 of Set 4 | upernavik
# Processing Record 46 of Set 4 | grevesmuhlen
# Processing Record 47 of Set 4 | elesbao veloso
# Processing Record 48 of Set 4 | fortuna
# Processing Record 49 of Set 4 | lebu
# Processing Record 50 of Set 4 | kremenki
# Processing Record 1 of Set 5 | kavieng
# Processing Record 2 of Set 5 | torbay
# Processing Record 3 of Set 5 | cayenne
# Processing Record 4 of Set 5 | bilma
# Processing Record 5 of Set 5 | asfi
# Processing Record 6 of Set 5 | vestmannaeyjar
# Processing Record 7 of Set 5 | sao joao da barra
# Processing Record 8 of Set 5 | sharjah
# Processing Record 9 of Set 5 | hermanus
# Processing Record 10 of Set 5 | milingimbi
# City not found. Skipping...
# Processing Record 11 of Set 5 | gonaives
# Processing Record 12 of Set 5 | nome
# Processing Record 13 of Set 5 | sydney
# Processing Record 14 of Set 5 | azanka
# Processing Record 15 of Set 5 | port lincoln
# Processing Record 16 of Set 5 | port hardy
# Processing Record 17 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 5 | haines junction
# Processing Record 19 of Set 5 | lasa
# Processing Record 20 of Set 5 | saint george
# Processing Record 21 of Set 5 | biak
# Processing Record 22 of Set 5 | moctezuma
# Processing Record 23 of Set 5 | jiroft
# City not found. Skipping...
# Processing Record 24 of Set 5 | port blair
# Processing Record 25 of Set 5 | skjervoy
# Processing Record 26 of Set 5 | ipswich
# Processing Record 27 of Set 5 | belmonte
# Processing Record 28 of Set 5 | veraval
# Processing Record 29 of Set 5 | karaton
# Processing Record 30 of Set 5 | touros
# Processing Record 31 of Set 5 | monteagudo
# Processing Record 32 of Set 5 | luang prabang
# Processing Record 33 of Set 5 | umm lajj
# Processing Record 34 of Set 5 | marrakesh
# Processing Record 35 of Set 5 | krasnoselkup
# Processing Record 36 of Set 5 | lompoc
# Processing Record 37 of Set 5 | mago
# Processing Record 38 of Set 5 | dorado
# Processing Record 39 of Set 5 | damietta
# Processing Record 40 of Set 5 | port elizabeth
# Processing Record 41 of Set 5 | buritis
# Processing Record 42 of Set 5 | ponta do sol
# Processing Record 43 of Set 5 | kaitangata
# Processing Record 44 of Set 5 | buala
# Processing Record 45 of Set 5 | puerto escondido
# Processing Record 46 of Set 5 | lavrentiya
# Processing Record 47 of Set 5 | shuangcheng
# Processing Record 48 of Set 5 | sarangani
# Processing Record 49 of Set 5 | palmer
# Processing Record 50 of Set 5 | hendek
# Processing Record 1 of Set 6 | kudahuvadhoo
# Processing Record 2 of Set 6 | bonthe
# Processing Record 3 of Set 6 | segou
# Processing Record 4 of Set 6 | kissamos
# Processing Record 5 of Set 6 | lagoa
# Processing Record 6 of Set 6 | kampene
# Processing Record 7 of Set 6 | xining
# Processing Record 8 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 9 of Set 6 | zhanaozen
# Processing Record 10 of Set 6 | gigmoto
# Processing Record 11 of Set 6 | pineville
# Processing Record 12 of Set 6 | saint-augustin
# Processing Record 13 of Set 6 | meadow lake
# Processing Record 14 of Set 6 | carnarvon
# Processing Record 15 of Set 6 | mattru
# Processing Record 16 of Set 6 | provideniya
# Processing Record 17 of Set 6 | kuito
# Processing Record 18 of Set 6 | victoria
# Processing Record 19 of Set 6 | berlevag
# Processing Record 20 of Set 6 | barguzin
# Processing Record 21 of Set 6 | morros
# Processing Record 22 of Set 6 | kidal
# Processing Record 23 of Set 6 | businga
# Processing Record 24 of Set 6 | sedelnikovo
# City not found. Skipping...
# Processing Record 25 of Set 6 | bafq
# Processing Record 26 of Set 6 | avera
# Processing Record 27 of Set 6 | barcelos
# Processing Record 28 of Set 6 | emerald
# Processing Record 29 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 30 of Set 6 | polovinnoye
# Processing Record 31 of Set 6 | khudumelapye
# Processing Record 32 of Set 6 | anderson
# Processing Record 33 of Set 6 | kutum
# Processing Record 34 of Set 6 | bojnurd
# Processing Record 35 of Set 6 | polis
# Processing Record 36 of Set 6 | elizabeth city
# Processing Record 37 of Set 6 | kadhan
# Processing Record 38 of Set 6 | ler
# Processing Record 39 of Set 6 | hobyo
# Processing Record 40 of Set 6 | kununurra
# Processing Record 41 of Set 6 | comodoro rivadavia
# Processing Record 42 of Set 6 | san quintin
# Processing Record 43 of Set 6 | constitucion
# Processing Record 44 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 6 | lorengau
# Processing Record 46 of Set 6 | naryan-mar
# Processing Record 47 of Set 6 | gushi
# Processing Record 48 of Set 6 | guerrero negro
# Processing Record 49 of Set 6 | jumla
# Processing Record 50 of Set 6 | muroto
# Processing Record 1 of Set 7 | uyemskiy
# Processing Record 2 of Set 7 | abeche
# Processing Record 3 of Set 7 | ingham
# Processing Record 4 of Set 7 | ambilobe
# Processing Record 5 of Set 7 | ampanihy
# Processing Record 6 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 7 | ferme-neuve
# Processing Record 8 of Set 7 | alice
# Processing Record 9 of Set 7 | taitung
# Processing Record 10 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 7 | cochrane
# Processing Record 12 of Set 7 | tasiilaq
# Processing Record 13 of Set 7 | opuwo
# Processing Record 14 of Set 7 | nuuk
# Processing Record 15 of Set 7 | ulladulla
# Processing Record 16 of Set 7 | natal
# Processing Record 17 of Set 7 | khujner
# Processing Record 18 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 7 | hami
# Processing Record 20 of Set 7 | the pas
# Processing Record 21 of Set 7 | cidreira
# Processing Record 22 of Set 7 | chavakkad
# Processing Record 23 of Set 7 | pangody
# Processing Record 24 of Set 7 | fare
# Processing Record 25 of Set 7 | atambua
# Processing Record 26 of Set 7 | sekoma
# Processing Record 27 of Set 7 | goedereede
# Processing Record 28 of Set 7 | tilichiki
# Processing Record 29 of Set 7 | warrnambool
# Processing Record 30 of Set 7 | bambous virieux
# Processing Record 31 of Set 7 | bowen
# Processing Record 32 of Set 7 | denizli
# Processing Record 33 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 34 of Set 7 | ust-kuyga
# Processing Record 35 of Set 7 | codrington
# Processing Record 36 of Set 7 | rustenburg
# Processing Record 37 of Set 7 | akhalgori
# Processing Record 38 of Set 7 | sioux lookout
# Processing Record 39 of Set 7 | bako
# Processing Record 40 of Set 7 | kodinar
# Processing Record 41 of Set 7 | tazovskiy
# Processing Record 42 of Set 7 | kulhudhuffushi
# Processing Record 43 of Set 7 | canto do buriti
# Processing Record 44 of Set 7 | qaqortoq
# Processing Record 45 of Set 7 | altamira
# Processing Record 46 of Set 7 | camana
# Processing Record 47 of Set 7 | ancud
# Processing Record 48 of Set 7 | burnie
# Processing Record 49 of Set 7 | padre bernardo
# Processing Record 50 of Set 7 | wolmaranstad
# City not found. Skipping...
# Processing Record 1 of Set 8 | shelburne
# Processing Record 2 of Set 8 | faya
# Processing Record 3 of Set 8 | abu samrah
# Processing Record 4 of Set 8 | pa sang
# Processing Record 5 of Set 8 | leshukonskoye
# Processing Record 6 of Set 8 | vostok
# Processing Record 7 of Set 8 | mantua
# Processing Record 8 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 9 of Set 8 | turayf
# Processing Record 10 of Set 8 | shingu
# Processing Record 11 of Set 8 | potosi
# Processing Record 12 of Set 8 | hualmay
# Processing Record 13 of Set 8 | dandong
# Processing Record 14 of Set 8 | corni
# Processing Record 15 of Set 8 | ruteng
# Processing Record 16 of Set 8 | najran
# Processing Record 17 of Set 8 | san jeronimo
# Processing Record 18 of Set 8 | auki
# Processing Record 19 of Set 8 | kifri
# Processing Record 20 of Set 8 | otradinskiy
# City not found. Skipping...
# Processing Record 21 of Set 8 | rabo de peixe
# Processing Record 22 of Set 8 | bad sankt leonhard
# City not found. Skipping...
# Processing Record 23 of Set 8 | kharitonovo
# Processing Record 24 of Set 8 | llaillay
# Processing Record 25 of Set 8 | acapulco
# Processing Record 26 of Set 8 | namatanai
# Processing Record 27 of Set 8 | trincomalee
# Processing Record 28 of Set 8 | hassleholm
# Processing Record 29 of Set 8 | stonewall
# Processing Record 30 of Set 8 | saint-leu
# Processing Record 31 of Set 8 | shu
# Processing Record 32 of Set 8 | tautira
# Processing Record 33 of Set 8 | nampula
# Processing Record 34 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 8 | el alto
# Processing Record 36 of Set 8 | gold coast
# Processing Record 37 of Set 8 | isangel
# Processing Record 38 of Set 8 | assai
# Processing Record 39 of Set 8 | hasaki
# Processing Record 40 of Set 8 | hede
# Processing Record 41 of Set 8 | maymanak
# City not found. Skipping...
# Processing Record 42 of Set 8 | havelock
# Processing Record 43 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 8 | witbank
# Processing Record 45 of Set 8 | luangwa
# Processing Record 46 of Set 8 | fougamou
# Processing Record 47 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 48 of Set 8 | ostrovnoy
# Processing Record 49 of Set 8 | salalah
# Processing Record 50 of Set 8 | axim
# Processing Record 1 of Set 9 | grand-santi
# Processing Record 2 of Set 9 | lethem
# Processing Record 3 of Set 9 | nantucket
# Processing Record 4 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 9 | juneau
# Processing Record 6 of Set 9 | sechura
# Processing Record 7 of Set 9 | oranjemund
# Processing Record 8 of Set 9 | tikhvin
# Processing Record 9 of Set 9 | kruisfontein
# Processing Record 10 of Set 9 | pitimbu
# Processing Record 11 of Set 9 | northam
# Processing Record 12 of Set 9 | lahaina
# Processing Record 13 of Set 9 | la paz
# Processing Record 14 of Set 9 | culasi
# Processing Record 15 of Set 9 | floro
# Processing Record 16 of Set 9 | tahe
# Processing Record 17 of Set 9 | imbituba
# Processing Record 18 of Set 9 | namuac
# Processing Record 19 of Set 9 | qasigiannguit
# Processing Record 20 of Set 9 | koslan
# Processing Record 21 of Set 9 | doha
# Processing Record 22 of Set 9 | madimba
# Processing Record 23 of Set 9 | port macquarie
# Processing Record 24 of Set 9 | frystak
# Processing Record 25 of Set 9 | nanov
# Processing Record 26 of Set 9 | portland
# Processing Record 27 of Set 9 | coquimbo
# Processing Record 28 of Set 9 | aitape
# Processing Record 29 of Set 9 | suntar
# Processing Record 30 of Set 9 | naze
# Processing Record 31 of Set 9 | iqaluit
# Processing Record 32 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 9 | viedma
# Processing Record 34 of Set 9 | flinders
# Processing Record 35 of Set 9 | pemangkat
# Processing Record 36 of Set 9 | mbanza-ngungu
# Processing Record 37 of Set 9 | yunhe
# Processing Record 38 of Set 9 | sorong
# Processing Record 39 of Set 9 | chatan
# Processing Record 40 of Set 9 | myitkyina
# Processing Record 41 of Set 9 | koungou
# Processing Record 42 of Set 9 | kumylzhenskaya
# Processing Record 43 of Set 9 | mandalgovi
# Processing Record 44 of Set 9 | sohag
# Processing Record 45 of Set 9 | canitas
# City not found. Skipping...
# Processing Record 46 of Set 9 | othonoi
# City not found. Skipping...
# Processing Record 47 of Set 9 | marostica
# Processing Record 48 of Set 9 | muros
# Processing Record 49 of Set 9 | nador
# Processing Record 50 of Set 9 | sulangan
# Processing Record 1 of Set 10 | shimoda
# Processing Record 2 of Set 10 | lokken verk
# City not found. Skipping...
# Processing Record 3 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 10 | hovd
# Processing Record 5 of Set 10 | aden
# Processing Record 6 of Set 10 | ust-omchug
# Processing Record 7 of Set 10 | mount gambier
# Processing Record 8 of Set 10 | navolato
# Processing Record 9 of Set 10 | vanimo
# Processing Record 10 of Set 10 | krasnopavlivka
# Processing Record 11 of Set 10 | kloulklubed
# Processing Record 12 of Set 10 | el dorado
# Processing Record 13 of Set 10 | sukagawa
# Processing Record 14 of Set 10 | tanout
# Processing Record 15 of Set 10 | portree
# Processing Record 16 of Set 10 | guacara
# Processing Record 17 of Set 10 | rundu
# Processing Record 18 of Set 10 | komsomolskiy
# Processing Record 19 of Set 10 | mayna
# Processing Record 20 of Set 10 | sur
# Processing Record 21 of Set 10 | yanchukan
# City not found. Skipping...
# Processing Record 22 of Set 10 | puerto penasco
# Processing Record 23 of Set 10 | santa cruz de la palma
# Processing Record 24 of Set 10 | sitka
# Processing Record 25 of Set 10 | molln
# Processing Record 26 of Set 10 | cavan
# Processing Record 27 of Set 10 | vilyuysk
# Processing Record 28 of Set 10 | batemans bay
# Processing Record 29 of Set 10 | coruripe
# Processing Record 30 of Set 10 | pangkalanbuun
# Processing Record 31 of Set 10 | nabire
# Processing Record 32 of Set 10 | warrington
# Processing Record 33 of Set 10 | darayya
# Processing Record 34 of Set 10 | tereze
# Processing Record 35 of Set 10 | berdigestyakh
# Processing Record 36 of Set 10 | panzhihua
# Processing Record 37 of Set 10 | wapi pathum
# Processing Record 38 of Set 10 | temiscaming
# Processing Record 39 of Set 10 | stillwater
# Processing Record 40 of Set 10 | ayorou
# Processing Record 41 of Set 10 | khasan
# Processing Record 42 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 43 of Set 10 | himora
# City not found. Skipping...
# Processing Record 44 of Set 10 | davila
# Processing Record 45 of Set 10 | solaro
# Processing Record 46 of Set 10 | prainha
# Processing Record 47 of Set 10 | los llanos de aridane
# Processing Record 48 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 10 | puerto cabezas
# Processing Record 50 of Set 10 | ranfurly
# Processing Record 1 of Set 11 | fukue
# Processing Record 2 of Set 11 | katsuura
# Processing Record 3 of Set 11 | baracoa
# Processing Record 4 of Set 11 | fort nelson
# Processing Record 5 of Set 11 | dalianwan
# Processing Record 6 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 11 | sao filipe
# Processing Record 8 of Set 11 | benghazi
# Processing Record 9 of Set 11 | ucluelet
# Processing Record 10 of Set 11 | renfrew
# Processing Record 11 of Set 11 | kovdor
# Processing Record 12 of Set 11 | moshenskoye
# Processing Record 13 of Set 11 | port keats
# Processing Record 14 of Set 11 | honiara
# Processing Record 15 of Set 11 | tongzi
# Processing Record 16 of Set 11 | bull savanna
# Processing Record 17 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 11 | namwala
# Processing Record 19 of Set 11 | kabare
# Processing Record 20 of Set 11 | takoradi
# Processing Record 21 of Set 11 | yeniseysk
# Processing Record 22 of Set 11 | latung
# Processing Record 23 of Set 11 | maragogi
# Processing Record 24 of Set 11 | hamilton
# Processing Record 25 of Set 11 | rocha
# Processing Record 26 of Set 11 | tarrega
# Processing Record 27 of Set 11 | dunedin
# Processing Record 28 of Set 11 | jasper
# Processing Record 29 of Set 11 | marawi
# Processing Record 30 of Set 11 | schattdorf
# Processing Record 31 of Set 11 | arawa
# Processing Record 32 of Set 11 | vitim
# Processing Record 33 of Set 11 | north shore
# Processing Record 34 of Set 11 | itamaraca
# Processing Record 35 of Set 11 | didsbury
# Processing Record 36 of Set 11 | mao
# Processing Record 37 of Set 11 | gryazi
# Processing Record 38 of Set 11 | baherden
# Processing Record 39 of Set 11 | lyubymivka
# Processing Record 40 of Set 11 | port augusta
# Processing Record 41 of Set 11 | bundaberg
# Processing Record 42 of Set 11 | qui nhon
# Processing Record 43 of Set 11 | klaksvik
# Processing Record 44 of Set 11 | crateus
# Processing Record 45 of Set 11 | visnes
# Processing Record 46 of Set 11 | terra santa
# Processing Record 47 of Set 11 | coihaique
# Processing Record 48 of Set 11 | plettenberg bay
# Processing Record 49 of Set 11 | venado tuerto
# Processing Record 50 of Set 11 | alpena
# Processing Record 1 of Set 12 | maine-soroa
# Processing Record 2 of Set 12 | catuday
# Processing Record 3 of Set 12 | taoudenni
# Processing Record 4 of Set 12 | nicoya
# Processing Record 5 of Set 12 | balakliya
# Processing Record 6 of Set 12 | jacareacanga
# Processing Record 7 of Set 12 | sydney mines
# Processing Record 8 of Set 12 | bitung
# Processing Record 9 of Set 12 | maningrida
# Processing Record 10 of Set 12 | ust-tsilma
# Processing Record 11 of Set 12 | marzuq
# Processing Record 12 of Set 12 | trairi
# Processing Record 13 of Set 12 | termiz
# Processing Record 14 of Set 12 | maurepas
# Processing Record 15 of Set 12 | lillooet
# Processing Record 16 of Set 12 | kars
# Processing Record 17 of Set 12 | aklavik
# Processing Record 18 of Set 12 | makakilo city
# Processing Record 19 of Set 12 | yialos
# City not found. Skipping...
# Processing Record 20 of Set 12 | embu
# Processing Record 21 of Set 12 | mayumba
# Processing Record 22 of Set 12 | mount isa
# Processing Record 23 of Set 12 | kangasala
# Processing Record 24 of Set 12 | elban
# Processing Record 25 of Set 12 | atar
# Processing Record 26 of Set 12 | antofagasta
# Processing Record 27 of Set 12 | ena
# Processing Record 28 of Set 12 | male
# Processing Record 29 of Set 12 | ossora
# Processing Record 30 of Set 12 | college
# Processing Record 31 of Set 12 | huazolotitlan
# City not found. Skipping...
# Processing Record 32 of Set 12 | novikovo
# Processing Record 33 of Set 12 | iquique
# Processing Record 34 of Set 12 | yaan
# Processing Record 35 of Set 12 | changji
# Processing Record 36 of Set 12 | toktogul
# Processing Record 37 of Set 12 | edd
# Processing Record 38 of Set 12 | richards bay
# Processing Record 39 of Set 12 | calamar
# Processing Record 40 of Set 12 | shenzhen
# Processing Record 41 of Set 12 | licheng
# Processing Record 42 of Set 12 | kumluca
# Processing Record 43 of Set 12 | nouakchott
# Processing Record 44 of Set 12 | zeerust
# Processing Record 45 of Set 12 | zambezi
# Processing Record 46 of Set 12 | galveston
# Processing Record 47 of Set 12 | morden
# Processing Record 48 of Set 12 | varnamo
# Processing Record 49 of Set 12 | acarau
# Processing Record 50 of Set 12 | puliyur
# Processing Record 1 of Set 13 | muana
# Processing Record 2 of Set 13 | pala
# Processing Record 3 of Set 13 | svetlaya
# Processing Record 4 of Set 13 | merauke
# Processing Record 5 of Set 13 | masty
# Processing Record 6 of Set 13 | la asuncion
# Processing Record 7 of Set 13 | fergus falls
# Processing Record 8 of Set 13 | omsukchan
# Processing Record 9 of Set 13 | mazatlan
# Processing Record 10 of Set 13 | barra dos coqueiros
# Processing Record 11 of Set 13 | bail hongal
# Processing Record 12 of Set 13 | ararangua
# Processing Record 13 of Set 13 | madang
# Processing Record 14 of Set 13 | ritchie
# Processing Record 15 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 13 | snyder
# Processing Record 17 of Set 13 | charlestown
# Processing Record 18 of Set 13 | jiuquan
# Processing Record 19 of Set 13 | vezirkopru
# Processing Record 20 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 21 of Set 13 | velingara
# Processing Record 22 of Set 13 | caravelas
# Processing Record 23 of Set 13 | witu
# Processing Record 24 of Set 13 | de-kastri
# Processing Record 25 of Set 13 | salta
# Processing Record 26 of Set 13 | belyy yar
# Processing Record 27 of Set 13 | ixtapa
# Processing Record 28 of Set 13 | sars
# Processing Record 29 of Set 13 | howard springs
# Processing Record 30 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 13 | uk
# City not found. Skipping...
# Processing Record 32 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 33 of Set 13 | bathsheba
# Processing Record 34 of Set 13 | dryden
# Processing Record 35 of Set 13 | misasi
# Processing Record 36 of Set 13 | walvis bay
# Processing Record 37 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 38 of Set 13 | girvan
# Processing Record 39 of Set 13 | wladyslawowo
# Processing Record 40 of Set 13 | tabou
# Processing Record 41 of Set 13 | lenger
# Processing Record 42 of Set 13 | austin
# Processing Record 43 of Set 13 | olkhovka
# Processing Record 44 of Set 13 | road town
# Processing Record 45 of Set 13 | lumeje
# Processing Record 46 of Set 13 | belaya gora
# Processing Record 47 of Set 13 | kaduna
# Processing Record 48 of Set 13 | bure
# Processing Record 49 of Set 13 | nong ki
# Processing Record 50 of Set 13 | soubre
# Processing Record 1 of Set 14 | kondratovo
# Processing Record 2 of Set 14 | mwense
# Processing Record 3 of Set 14 | buston
# Processing Record 4 of Set 14 | ternate
# Processing Record 5 of Set 14 | abashiri
# Processing Record 6 of Set 14 | birao
# Processing Record 7 of Set 14 | jining
# Processing Record 8 of Set 14 | puerto del rosario
# Processing Record 9 of Set 14 | mayo
# Processing Record 10 of Set 14 | bairiki
# Processing Record 11 of Set 14 | launceston
# Processing Record 12 of Set 14 | jeremoabo
# Processing Record 13 of Set 14 | tokuyama
# Processing Record 14 of Set 14 | xinzhi
# Processing Record 15 of Set 14 | broome
# Processing Record 16 of Set 14 | sakakah
# Processing Record 17 of Set 14 | yatou
# Processing Record 18 of Set 14 | porbandar
# Processing Record 19 of Set 14 | gat
# Processing Record 20 of Set 14 | newport
# Processing Record 21 of Set 14 | bouar
# Processing Record 22 of Set 14 | apatou
# Processing Record 23 of Set 14 | lerwick
# Processing Record 24 of Set 14 | christchurch
# Processing Record 25 of Set 14 | sorland
# Processing Record 26 of Set 14 | monduli
# Processing Record 27 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 14 | scarborough
# Processing Record 29 of Set 14 | dakar
# Processing Record 30 of Set 14 | yefira
# City not found. Skipping...
# Processing Record 31 of Set 14 | hong gai
# Processing Record 32 of Set 14 | tezu
# Processing Record 33 of Set 14 | adeje
# Processing Record 34 of Set 14 | nioro
# Processing Record 35 of Set 14 | nelson bay
# Processing Record 36 of Set 14 | chara
# Processing Record 37 of Set 14 | port arthur
# Processing Record 38 of Set 14 | miraflores
# Processing Record 39 of Set 14 | hvolsvollur
# Processing Record 40 of Set 14 | toppenish
# Processing Record 41 of Set 14 | aswan
# Processing Record 42 of Set 14 | verkhoyansk
# Processing Record 43 of Set 14 | baie-comeau
# Processing Record 44 of Set 14 | mukono
# Processing Record 45 of Set 14 | srednekolymsk
# Processing Record 46 of Set 14 | preobrazheniye
# Processing Record 47 of Set 14 | bilibino
# Processing Record 48 of Set 14 | ljungby
# Processing Record 49 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 14 | nara
# Processing Record 1 of Set 15 | matadi
# Processing Record 2 of Set 15 | zlin
# Processing Record 3 of Set 15 | abomsa
# Processing Record 4 of Set 15 | mehamn
# Processing Record 5 of Set 15 | ipixuna
# Processing Record 6 of Set 15 | turochak
# Processing Record 7 of Set 15 | tahta
# Processing Record 8 of Set 15 | kargasok
# Processing Record 9 of Set 15 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 10 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 15 | dolgorukovo
# Processing Record 12 of Set 15 | hokitika
# Processing Record 13 of Set 15 | rondonopolis
# Processing Record 14 of Set 15 | saint-pierre
# Processing Record 15 of Set 15 | iquitos
# Processing Record 16 of Set 15 | yeppoon
# Processing Record 17 of Set 15 | temir
# Processing Record 18 of Set 15 | malvern
# Processing Record 19 of Set 15 | anloga
# Processing Record 20 of Set 15 | cap malheureux
# Processing Record 21 of Set 15 | zhigansk
# Processing Record 22 of Set 15 | manzhouli
# Processing Record 23 of Set 15 | yanam
# Processing Record 24 of Set 15 | gamboma
# Processing Record 25 of Set 15 | oussouye
# Processing Record 26 of Set 15 | surt
# Processing Record 27 of Set 15 | mudyuga
# City not found. Skipping...
# Processing Record 28 of Set 15 | hulan
# Processing Record 29 of Set 15 | namibe
# Processing Record 30 of Set 15 | halifax
# Processing Record 31 of Set 15 | chicama
# Processing Record 32 of Set 15 | malinovskiy
# Processing Record 33 of Set 15 | itarare
# Processing Record 34 of Set 15 | nouadhibou
# Processing Record 35 of Set 15 | karasjok
# Processing Record 36 of Set 15 | rovinj
# Processing Record 37 of Set 15 | mumbwa
# Processing Record 38 of Set 15 | bathurst
# Processing Record 39 of Set 15 | gamba
# Processing Record 40 of Set 15 | devon
# Processing Record 41 of Set 15 | thiers
# Processing Record 42 of Set 15 | rio branco
# Processing Record 43 of Set 15 | coahuayana
# Processing Record 44 of Set 15 | nanning
# Processing Record 45 of Set 15 | san carlos de bariloche
# Processing Record 46 of Set 15 | talaya
# Processing Record 47 of Set 15 | taybad
# Processing Record 48 of Set 15 | kilindoni
# Processing Record 49 of Set 15 | tessalit
# Processing Record 50 of Set 15 | abha
# Processing Record 1 of Set 16 | upata
# Processing Record 2 of Set 16 | enshi
# Processing Record 3 of Set 16 | kerman
# Processing Record 4 of Set 16 | markivka
# Processing Record 5 of Set 16 | kaeo
# Processing Record 6 of Set 16 | zapolyarnyy
# Processing Record 7 of Set 16 | ocumare del tuy
# Processing Record 8 of Set 16 | zhigalovo
# Processing Record 9 of Set 16 | dzhusaly
# City not found. Skipping...
# Processing Record 10 of Set 16 | gurskoye
# City not found. Skipping...
# Processing Record 11 of Set 16 | taltal
# Processing Record 12 of Set 16 | athabasca
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Port Alfred -33.5906   26.8910     60.19        85          10        3.00
# 1    Jamestown  42.0970  -79.2353     77.02        73          75        8.05
# 2      Rikitea -23.1203 -134.9692     72.82        74           3       15.43
# 3         Hilo  19.7297 -155.0900     82.26        84           3        1.99
# 4    Hithadhoo  -0.6000   73.0833     81.57        72           3        3.44
# 5        Tiksi  71.6872  128.8694     33.26        99         100       15.93
# 6        Pevek  69.7008  170.3133     34.61        77          49       10.58
# 7       Bethel  41.3712  -73.4140     78.19        62           0        5.01
# 8      Ushuaia -54.8000  -68.3000     44.44        79          59       11.68
# 9      Aguimes  27.9054  -15.4461     77.67        69          20       17.27
#
#   Country Current Description
# 0      ZA           clear sky
# 1      US       broken clouds
# 2      PF           clear sky
# 3      US           clear sky
# 4      MV           clear sky
# 5      RU                snow
# 6      RU    scattered clouds
# 7      US           clear sky
# 8      AR       broken clouds
# 9      ES          few clouds

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
